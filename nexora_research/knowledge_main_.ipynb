# %% [markdown]
# ### 🚫 Bad Version (messy & unsafe)

# %%
# math_tools.py

def add(a, b):
    return a + b

def multiply(a, b):
    return a * b

# ❌ Bad: running code at import time
print("I am in math_tools.py")
print("__name__ is:", __name__)
print("math_tools.py was imported")
# Out:
# I am in math_tools.py
# __name__ is: __main__
# math_tools.py was imported

# %%
# app.py
from math_tools import add, multiply

print("I am in app.py")
print("__name__ is:", __name__)
print("Running app.py directly")

result = add(3, 4)
print("3 + 4 =", result)

# %% [markdown]
# ### ✅ Good Version (professional & safe)

# %%
# app.py
from math_tools import add, multiply

print("I am in app.py")
print("__name__ is:", __name__)
print("Running app.py directly")

result = add(3, 4)
print("3 + 4 =", result)

# %%
# app.py
from math_tools import add, multiply

def main():
    result1 = add(3, 4)
    result2 = multiply(2, 5)

    print("I am in app.py")
    print("__name__ is:", __name__)
    print("3 + 4 =", result1)
    print("2 * 5 =", result2)

if __name__ == "__main__":
    main()

# %% [markdown]
# Perfect, Deepankar 👍
# Let’s make this crystal clear with both **concept** and **examples**.
#
# ---
#
# ## 🔑 Concept
#
# 1. Every Python file has a special variable `__name__`.
# 2. When you **run a file directly**, Python sets `__name__ = "__main__"`.
# 3. When you **import a file**, Python sets `__name__ = "<module_name>"`.
# 4. Therefore:
#
#    * Code inside `if __name__ == "__main__":` → runs **only** when the file is executed directly.
#    * Code outside that guard → always runs, even on import.
#
# 👉 The guard is how you stop helper modules from executing “demo” or “script” code when they are just imported.
#
# ---
#
# ## ❌ Bad Example (without guard)
#
# `math_tools.py`
#
# ```python
# print("I am in math_tools.py")   # runs on import too
# print("__name__ is:", __name__)
#
# def add(a, b):
#     return a + b
#
# print("Running math_tools.py directly")  # also runs on import (BAD)
# ```
#
# `app.py`
#
# ```python
# import math_tools
#
# print("I am in app.py")
# print("__name__ is:", __name__)
# ```
#
# **Output when running `python app.py`:**
#
# ```
# I am in math_tools.py
# __name__ is: math_tools
# Running math_tools.py directly   <-- BAD, this ran on import
# I am in app.py
# __name__ is: __main__
# ```
#
# 👉 Problem: helper file (`math_tools.py`) ran extra code on import.
#
# ---
#
# ## ✅ Good Example (with guard)
#
# `math_tools.py`
#
# ```python
# print("math_tools.py loaded")  # Optional, but even this is usually avoided
#
# def add(a, b):
#     return a + b
#
# # Only runs if executed directly
# if __name__ == "__main__":
#     print("Running math_tools.py directly")
#     print("2 + 3 =", add(2, 3))
# ```
#
# `app.py`
#
# ```python
# import math_tools
#
# print("I am in app.py")
# print("__name__ is:", __name__)
#
# if __name__ == "__main__":
#     print("Running app.py directly")
# ```
#
# **Output when running `python app.py`:**
#
# ```
# math_tools.py loaded
# I am in app.py
# __name__ is: __main__
# Running app.py directly
# ```
#
# **Output when running `python math_tools.py`:**
#
# ```
# math_tools.py loaded
# Running math_tools.py directly
# 2 + 3 = 5
# ```
#
# 👉 Clean behavior:
#
# * When **imported** → only functions/classes load, no extra execution.
# * When **run directly** → extra test/demo code runs.
#
# ---
#
# ## ✅ Rule of Thumb (Professional Code)
#
# * **Helper/library modules** (e.g., `math_tools.py`) → put only function/class definitions. If you want test/demo code, protect it under `if __name__ == "__main__":`.
# * **Main entrypoint scripts** (e.g., `app.py`) → here you place your real execution flow, also usually inside `if __name__ == "__main__":`.
#
# ---
#
# Would you like me to also show you how **large projects** usually structure this pattern (with `main()` function inside `app.py`), so it looks professional and scalable?

# %% [markdown]
# Great question, Deepankar 🙌 — this is the subtle part where people often misuse `__main__` in helper modules. Let me break it down for you.
#
# ---
#
# ## 🧑‍💻 Rule of Thumb for `if __name__ == "__main__":` in Helper Modules
#
# 👉 **You don’t *need* it in helper modules most of the time.**
# Helper modules (like `math_tools.py`) are usually **meant to be imported only**.
#
# But sometimes it makes sense to include it:
#
# ---
#
# ### ✅ When to include `__main__` in helper modules:
#
# 1. **For quick standalone testing**
#
#    * If you want to be able to run `python math_tools.py` just to check functions work.
#    * Example:
#
#      ```python
#      def add(a, b):
#          return a + b
#
#      if __name__ == "__main__":
#          # Run some quick sanity tests
#          print("Testing add():")
#          print("2 + 3 =", add(2, 3))
#      ```
#
# 2. **For development/debugging convenience**
#
#    * You can put demo/test code in there.
#    * It won’t run when imported into another script.
#
# ---
#
# ### ❌ When **not** to include it:
#
# * If the file is purely **utility code** that should never run standalone (e.g., database models, configs, constants).
# * Example: `constants.py` with only variables like `API_KEY`, `MAX_RETRIES`, etc. → no need for `__main__`.
#
# ---
#
# ## 🔑 Key Difference
#
# * `__main__` in **helper modules** → optional, for testing/debugging only.
# * `__main__` in **entrypoint (like `app.py`)** → required, to define the actual start of the program.
#
# ---
#
# ## 📊 Example
#
# ### `math_tools.py` (helper with demo)
#
# ```python
# def multiply(a, b):
#     return a * b
#
# if __name__ == "__main__":
#     print("Demo: Testing multiply()")
#     print("3 * 4 =", multiply(3, 4))
# ```
#
# * Running `python math_tools.py` → demo runs.
# * Importing into `app.py` → only `multiply` is imported (demo is skipped).
#
# ---
#
# ### `app.py` (entrypoint)
#
# ```python
# from math_tools import multiply
#
# def main():
#     print("Running main app...")
#     print("10 * 5 =", multiply(10, 5))
#
# if __name__ == "__main__":
#     main()
# ```
#
# * Running `python app.py` → full app runs.
# * Importing into tests → nothing auto-executes.
#
# ---
#
# ✅ This way you can **test helpers independently** if needed.
# ✅ But for professional projects, helpers usually don’t have `__main__` unless you want a **quick sanity check**.
#
# ---
#
# Deepankar, do you want me to show you a **real-world pattern** where helper modules have a `__main__` for unit-test style checks (like `python db_utils.py` runs a connection test)? That’s a neat professional trick.

# %% [markdown]
# Perfect, Deepankar 🚀
# Let’s walk through how **professional / large Python projects** structure `__main__` in their entry scripts (`app.py`) so code is clean, testable, and scalable.
#
# ---
#
# ## 🔑 Best Practices in Large Projects
#
# 1. **Keep reusable logic in functions/classes** → never dump everything at the top level.
# 2. **Create a `main()` function** → where the actual execution logic lives.
# 3. **Use `if __name__ == "__main__": main()`** → so the program only runs when executed directly.
# 4. **Helper modules stay clean** → no side effects on import.
#
# ---
#
# ## 🏗️ Example Project Structure
#
# ```
# my_project/
# │
# ├── math_tools.py      # Helper functions
# ├── utils.py           # Other utilities
# ├── app.py             # Main entrypoint
# └── __init__.py        # Marks package (optional)
# ```
#
# ---
#
# ### `math_tools.py` (Helper module)
#
# ```python
# def add(a: int, b: int) -> int:
#     return a + b
#
# def subtract(a: int, b: int) -> int:
#     return a - b
#
# if __name__ == "__main__":
#     # Demo code, useful for testing this file independently
#     print("Demo: Running math_tools directly")
#     print("2 + 3 =", add(2, 3))
#     print("5 - 1 =", subtract(5, 1))
# ```
#
# ✅ When imported, only `add` and `subtract` load.
# ✅ When run directly (`python math_tools.py`), demo code executes.
#
# ---
#
# ### `app.py` (Main entry script)
#
# ```python
# from math_tools import add, subtract
#
# def main():
#     print("App started...")
#
#     x, y = 10, 5
#     print(f"{x} + {y} = {add(x, y)}")
#     print(f"{x} - {y} = {subtract(x, y)}")
#
# if __name__ == "__main__":
#     main()
# ```
#
# ✅ `main()` is the clean execution entry.
# ✅ If you import `app` somewhere else (e.g., for testing), the program won’t start automatically.
#
# ---
#
# ## 📊 Behavior
#
# 1. Running `python app.py`:
#
# ```
# App started...
# 10 + 5 = 15
# 10 - 5 = 5
# ```
#
# 2. Running `python math_tools.py`:
#
# ```
# Demo: Running math_tools directly
# 2 + 3 = 5
# 5 - 1 = 4
# ```
#
# 3. Importing inside REPL:
#
# ```python
# >>> import math_tools
# >>> math_tools.add(7, 8)
# 15
# ```
#
# (No extra prints!)
#
# ---
#
# ## 🚀 Why this is professional & scalable?
#
# * **Clear entrypoint (`app.py`)** → easy for team members to know where to run the program.
# * **Helper modules are import-safe** → no side effects, no messy logs.
# * **Testing is easier** → you can import `main()` into a test runner without triggering execution.
# * **Reusable** → the same `math_tools` module can be reused in multiple apps.
#
# ---
#
# Deepankar, do you want me to show you how this pattern looks in **enterprise projects** (with `src/`, `tests/`, and a `cli.py` entrypoint)? That’s the next level.
